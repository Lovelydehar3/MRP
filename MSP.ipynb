# %%
# --------------------------------------------------
# 🧪 Phase 1: Data Loading, Inspection & Visualization
# --------------------------------------------------

# 📦 Importing essential libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# To display plots inside notebook
# %matplotlib inline

# %%
# 🗂 Reading both CSV files
movies= pd.read_csv("movies.csv")
ratings= pd.read_csv("ratings.csv")

# %%
# 🔍 Check shape of both datasets
print("Movies Dataset Shape:", movies.shape)
print("Ratings Dataset Shape:", ratings.shape)
# Out:
# Movies Dataset Shape: (4803, 4)
# Ratings Dataset Shape: (4803, 20)

# %%
# 🧾 Display first few rows
print("\n🎬 Movies Sample:")
display(movies.head())

print("\n⭐ Ratings Sample:")
display(ratings.head())
# Out:
# 🎬 Movies Sample:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
# 🔍 Checking column names
print("\n🎯 Movies Columns:", movies.columns.tolist())
print("🎯 Ratings Columns:", ratings.columns.tolist())
# Out:
# 🎯 Movies Columns: ['movie_id', 'title', 'cast', 'crew']
# 🎯 Ratings Columns: ['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language', 'original_title', 'overview', 'popularity', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'vote_average', 'vote_count']

# %%
# ℹ️ Info about both datasets
print("\n📊 Movies Dataset Info:")
movies.info()
# Out:
# 📊 Movies Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %%
print("\n📊 Ratings Dataset Info:")
ratings.info()
# Out:
# 📊 Ratings Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
# ...

# %%
# 🧼 Missing values in both datasets
print("\n❓ Missing Values in Movies:")
print(movies.isnull().sum())

print("\n❓ Missing Values in Ratings:")
print(ratings.isnull().sum())
# Out:
# ❓ Missing Values in Movies:
# movie_id    0
# title       0
# cast        0
# crew        0
# dtype: int64
#
# ❓ Missing Values in Ratings:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
# Heatmap for missing values in movies
plt.figure(figsize=(10, 4))
sns.heatmap(movies.isnull(), cbar=False, cmap='Reds')
plt.title("Missing Values in Movies Dataset")
plt.show()

# Heatmap for missing values in ratings
plt.figure(figsize=(10, 4))
sns.heatmap(ratings.isnull(), cbar=False, cmap='Blues')
plt.title("Missing Values in Ratings Dataset")
plt.show()

# %% [markdown]
# ## ✅ Phase 1 Summary:
#
# - Loaded both `movies.csv` and `ratings.csv`.
# - Inspected shapes, columns, and missing values.
# - Visualized missing data using heatmaps.
# - Plotted the distribution of movie ratings.
#
# ➡️ Ready for Phase 2: **Numerical Features Analysis (with visualizations)**.

# %%
# --------------------------------------------------
# 🔢 Phase 2: Numerical Feature Analysis & Visualization
# --------------------------------------------------

# 📌 Selecting numerical columns
numerical_cols = ['budget', 'popularity', 'revenue', 'runtime', 'vote_average', 'vote_count']
numerical_df = ratings[numerical_cols]

# 📊 Summary statistics
print("📈 Summary Statistics of Numerical Features:")
display(numerical_df.describe())
# Out:
# 📈 Summary Statistics of Numerical Features:
#              budget   popularity       revenue      runtime  vote_average  \
# count  4.803000e+03  4803.000000  4.803000e+03  4801.000000   4803.000000
# mean   2.904504e+07    21.492301  8.226064e+07   106.875859      6.092172
# std    4.072239e+07    31.816650  1.628571e+08    22.611935      1.194612
# min    0.000000e+00     0.000000  0.000000e+00     0.000000      0.000000
# 25%    7.900000e+05     4.668070  0.000000e+00    94.000000      5.600000
# 50%    1.500000e+07    12.921594  1.917000e+07   103.000000      6.200000
# 75%    4.000000e+07    28.313505  9.291719e+07   118.000000      6.800000
# max    3.800000e+08   875.581305  2.787965e+09   338.000000     10.000000
#
#          vote_count
# count   4803.000000
# mean     690.217989
# std     1234.585891
# min        0.000000
# 25%       54.000000
# 50%      235.000000
# 75%      737.000000
# max    13752.000000

# %%
# 📊 Histograms for all numerical columns
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(2, 3, i+1)
    sns.histplot(ratings[col], kde=True, color='red')
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
# 📦 Boxplots for numerical columns
plt.figure(figsize=(16, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(2, 3, i+1)
    sns.boxplot(data=ratings[col], color='salmon')
    plt.title(f"Boxplot of {col}")
plt.tight_layout()
plt.show()

# %%
# 🔗 Correlation heatmap between numerical features
plt.figure(figsize=(8, 6))
sns.heatmap(numerical_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation between Numerical Features")
plt.show()

# %% [markdown]
# ## ✅ Phase 2 Summary:
#
# - Selected 6 key numerical features: budget, popularity, revenue, runtime, vote_average, vote_count.
# - Analyzed distributions using histograms and KDE plots.
# - Detected outliers using boxplots.
# - Visualized feature correlation with heatmap.
#
# ➡️ Ready to move to Phase 3: **Categorical Feature Analysis**

# %%
# --------------------------------------------------
# 🧩 Phase 3: Categorical Feature Analysis
# --------------------------------------------------

# 📌 Select simple categorical columns first
categorical_cols = ['original_language', 'status']

# 📊 Unique values and counts
for col in categorical_cols:
    print(f"\n🟨 Column: {col}")
    print("Unique values:", ratings[col].nunique())
    print(ratings[col].value_counts())
# Out:
# 🟨 Column: original_language
# Unique values: 37
# original_language
# en    4505
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# cn      12
# ko      11
# ru      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# id       2
# cs       2
# ta       2
# ro       2
# ar       2
# te       1
# hu       1
# xx       1
# af       1
# is       1
# tr       1
# vi       1
# pl       1
# nb       1
# ky       1
# no       1
# sl       1
# ps       1
# el       1
# Name: count, dtype: int64
#
# 🟨 Column: status
# Unique values: 3
# status
# Released           4795
# Rumored               5
# Post Production       3
# Name: count, dtype: int64

# %%
# ✅ Countplot for original_language (future-safe)
plt.figure(figsize=(10, 4))
sns.countplot(
    data=ratings,
    x='original_language',
    order=ratings['original_language'].value_counts().index[:10],
    hue='original_language',  # set x also as hue
    palette='Set2',
    legend=False              # hide redundant legend
)
plt.title("Top 10 Languages Used in Movies")
plt.xticks(rotation=45)
plt.show()

# %%
# ✅ Countplot for movie status (future-safe)
plt.figure(figsize=(6, 4))
sns.countplot(
    data=ratings,
    x='status',
    hue='status',
    palette='coolwarm',
    legend=False
)
plt.title("Movie Status Count")
plt.show()

# %%
# 🧹 Extract genres from string to list
import ast

# Convert stringified list to actual list
ratings['genres'] = ratings['genres'].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else [])

# Extract genre names
def extract_genre_names(genres):
    return [genre['name'] for genre in genres]

ratings['genre_names'] = ratings['genres'].apply(extract_genre_names)

# %%
# ✅ Barplot for Top Genres (no warning)
plt.figure(figsize=(10, 5))
sns.barplot(
    data=genre_df.head(10),
    x='Genre',
    y='Count',
    hue='Genre',          # setting hue same as x
    palette='viridis',
    legend=False          # hide repeated legend
)
plt.title("Top 10 Most Common Genres")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## ✅ Phase 3 Summary:
#
# - Analyzed simple categorical columns like `original_language` and `status`.
# - Extracted and visualized top genres from JSON-like format.
# - Used countplots and barplots for visualization.
#
# ➡️ Ready for Phase 4: **Mixed Feature Analysis** (complex columns like cast, crew, etc.)

# %%
import ast
from collections import Counter

# ✅ Fix: Use the correct DataFrame: 'movies'
movies['cast'] = movies['cast'].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else [])

# 🎭 Extract top 3 actors from cast
def extract_actors(cast_list):
    return [member['name'] for member in cast_list[:3]]

movies['top_actors'] = movies['cast'].apply(extract_actors)

# Flatten all actor names
all_actors = sum(movies['top_actors'], [])
actor_counts = Counter(all_actors).most_common(10)

# Convert to DataFrame
actor_df = pd.DataFrame(actor_counts, columns=['Actor', 'Count'])

# 📊 Barplot
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
sns.barplot(data=actor_df, x='Actor', y='Count', hue='Actor', palette='cubehelix', legend=False)
plt.title("Top 10 Most Frequent Actors")
plt.xticks(rotation=45)
plt.show()

# %%
import ast
from collections import Counter

# ✅ Safely parse 'cast' field
def safe_eval_cast(x):
    if isinstance(x, str):
        try:
            return ast.literal_eval(x)
        except:
            return []
    elif isinstance(x, list):
        return x
    else:
        return []

movies['cast'] = movies['cast'].apply(safe_eval_cast)

# 🎭 Extract top 3 actors
def extract_actors(cast_list):
    return [member['name'] for member in cast_list[:3]]

movies['top_actors'] = movies['cast'].apply(extract_actors)

# Flatten all actors and count
all_actors = sum(movies['top_actors'], [])
actor_counts = Counter(all_actors).most_common(10)
actor_df = pd.DataFrame(actor_counts, columns=['Actor', 'Count'])

# 📊 Barplot
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
sns.barplot(data=actor_df, x='Actor', y='Count', hue='Actor', palette='cubehelix', legend=False)
plt.title("Top 10 Most Frequent Actors")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h5>Phase 4: Feature Engineering with different types of graphs to make the project more visual and insightful. We'll focus on
# Cast Analysis 👨‍🎤
#
# Crew Analysis 🎬
#
# Genre Analysis 🎭
#
# Keyword Analysis 🔑
#
# Release Date Features 📅
#
# Runtime Buckets ⏱️
#
# Language & Status 📣
#
# Popularity, Vote Analysis, Revenue vs Budget 📈
#
# Correlation Heatmap 🌡️###</h5>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# Set default Seaborn style
sns.set(style="whitegrid")

# Read your CSV files
movies = pd.read_csv("movies.csv")        # contains ['movie_id', 'title', 'cast', 'crew']
ratings = pd.read_csv("ratings.csv")      # contains many features like genres, runtime, revenue etc.

# Merge both on 'title'
df = pd.merge(ratings, movies, on='title')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data (replace with your correct path)
movies = pd.read_csv("movies.csv")
ratings = pd.read_csv("ratings.csv")

# Merge on 'title'
df = pd.merge(ratings, movies, on='title')

# ------------ Feature 1: Genre Count ------------ #
df['genres'] = df['genres'].fillna('')
df['genres'] = df['genres'].apply(lambda x: x.replace('[','').replace(']','').replace("'",'').replace(" ",''))
genres_list = df['genres'].str.split(',')
all_genres = [genre for sublist in genres_list for genre in sublist if genre != '']
genre_df = pd.Series(all_genres).value_counts().reset_index()
genre_df.columns = ['Genre', 'Count']

plt.figure(figsize=(8,5))
sns.barplot(data=genre_df.head(10), x='Genre', y='Count')
plt.title('Top 10 Genres')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# ------------ Feature 2: Original Language ------------ #
lang_df = df['original_language'].value_counts().head(10)

plt.figure(figsize=(8,5))
lang_df.plot(kind='bar', color='skyblue')
plt.title('Top 10 Languages')
plt.xlabel('Language')
plt.ylabel('Number of Movies')
plt.tight_layout()
plt.show()

# ------------ Feature 3: Budget vs Revenue ------------ #
df_budget = df[(df['budget'] > 0) & (df['revenue'] > 0)]

plt.figure(figsize=(8,5))
plt.scatter(df_budget['budget'], df_budget['revenue'], alpha=0.5)
plt.title('Budget vs Revenue')
plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.tight_layout()
plt.show()

# ------------ Feature 4: Runtime Distribution ------------ #
plt.figure(figsize=(8,5))
plt.hist(df['runtime'].dropna(), bins=30, color='orange', edgecolor='black')
plt.title('Runtime Distribution')
plt.xlabel('Runtime (minutes)')
plt.ylabel('Number of Movies')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h5>Bivariate Analysis</h5>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatter plot to see if high budget = high revenue
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='budget', y='revenue')
plt.title('Budget vs Revenue')
plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='runtime', y='vote_average')
plt.title('Runtime vs Average Rating')
plt.xlabel('Runtime')
plt.ylabel('Vote Average')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='popularity', y='vote_count')
plt.title('Popularity vs Vote Count')
plt.xlabel('Popularity')
plt.ylabel('Vote Count')
plt.show()
